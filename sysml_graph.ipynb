# %%
import json
import plotly.graph_objects as go
import networkx as nx
from plotly.offline import plot
import plotly.offline as pyo
import plotly.io as pio
pio.renderers.default='notebook'
#pyo.init_notebook_mode()    # initialize notebook for offline plot

# %%
# Load and parse the JSON file
with open('data/qrc.json', 'r') as json_file:
    data = json.load(json_file)

# Initialize a directed graph in networkx
G = nx.DiGraph()

# %%
# Process nodes and edges and build hover text details
node_info = {}
edge_hover_info = {}
for element in data:
    node_id = element.get('@id')
    if node_id:
        # Collect the required attributes, if present
        attributes = {
            '@type': element.get('@type', 'No Type'),
            'name': element.get('name', ''),
            'value': element.get('value', ''),
            'operator': element.get('operator', ''),
        }
        node_label = '\n'.join(f'{key}: {val}' for key, val in attributes.items() if val)
        G.add_node(node_id, label=node_label)
        # Store the full JSON data of the node for hover info
        node_info[node_id] = '<br>'.join([f'{k}: {v}' for k, v in element.items() if v])
        
    # Add edges and store connection data for hover info
    for key, value in element.items():
        if isinstance(value, dict) and value.get('@id'):
            target_id = value.get('@id')
            G.add_edge(node_id, target_id)
            edge_hover_info[(node_id, target_id)] = f'{key} → {target_id}'

# %%
# Use a layout algorithm to position the nodes
node_id_to_position = nx.spring_layout(G,  k=.15) # easier to read the labels
#node_id_to_position = nx.spectral_layout(G, scale=.1) # easer to see the arms of the graph

# %%
# Initialize edge trace for Plotly
edge_trace = go.Scatter(
    x=[],
    y=[],
    line=dict(width=1, color='#888'),
    hoverinfo='text',
    mode='lines',
    text=[])

# %%
# Add edge positions to the edge trace and the respective hover text
for edge in G.edges():
    x0, y0 = node_id_to_position[edge[0]]
    x1, y1 = node_id_to_position[edge[1]]
    edge_trace['x'] += (x0, x1, None)
    edge_trace['y'] += (y0, y1, None)
    edge_hover_text = edge_hover_info.get(edge, '')
    edge_trace['text'] += (edge_hover_text, edge_hover_text, None)

# %%
# Initialize node trace for Plotly
node_trace = go.Scatter(
    x=[],
    y=[],
    text=[],
    mode='markers+text',
    hovertext=[],
    hoverinfo='text',
    textposition='bottom center',
    marker=dict(
        showscale=False,
        color=[],  # Color will be added later
        size=10,
        line_width=2))

# %%
# Add node positions, labels, hover texts to the node trace, and define the color based on type
for node in G.nodes():
    x, y = node_id_to_position[node]
    node_type = G.nodes[node].get('label', '').split('\n')[0]  # Get the type label
    node_type_value = node_type.split(': ')[1] if ': ' in node_type else None
    
    # Set color based on the type
    node_color = 'red' if node_type_value in ['OperatorExpression', 'AttributeUsage', 'ReferenceUsage', 'ConstraintUsage'] else 'LightSkyBlue'
    
    node_trace['x'] += (x,)
    node_trace['y'] += (y,)
    node_trace['text'] += (G.nodes[node]['label'],)
    node_trace['hovertext'] += (node_info[node],)  # Fix: access node_info with node as key
    node_trace['marker']['color'] += (node_color,)  # Adding the color to the node trace

# %%
# Create the figure
fig = go.FigureWidget(data=[edge_trace, node_trace],
                layout=go.Layout(
                    title='Interactive SysMLv2 Network Graph',
                    titlefont_size=16,
                    height=800,
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=20, l=5, r=5, t=40),
                    xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                    yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

# %%
fig.show()
# Out:
# <div>                            <div id="832fa7e2-8d1b-40c5-9a5e-6413dff1ffe9" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("832fa7e2-8d1b-40c5-9a5e-6413dff1ffe9")) {                    Plotly.newPlot(                        "832fa7e2-8d1b-40c5-9a5e-6413dff1ffe9",                        [{"hoverinfo":"text","line":{"color":"#888","width":1},"mode":"lines","text":["ownedMemberFeature \u2192 bfe7bd8f-8dee-4635-b91c-9f27f685e926","ownedMemberFeature \u2192 bfe7bd8f-8dee-4635-b91c-9f27f685e926",null,"type \u2192 d1305691-d72d-485c-b957-392a140cdba9","type \u2192 d1305691-d72d-485c-b957-392a140cdba9",null,"owningUsage \u2192 d1305691-d72d-485c-b957-392a140cdba9","owningUsage \u2192 d1305691-d72d-485c-b957-392a140cdba9",null,"owningRelationship \u2192 635407dc-1fde-4315-a388-52a0fae347dd","owningRelationship \u2192 635407dc-1fde-4315-a388-52a0fae347dd",null,"owningType \u2192 1f505b70-008f-4d9f-8662-e43247298790","owningType \u2192 1f505b70-008f-4d9f-8662-e43247298790",null,"owningRelationship \u2192 997d7d4f-710b-48ba-9625-b9df7d0acb58","owningRelationship \u2192 997d7d4f-710b-48ba-9625-b9df7d0acb58",null,"owningType \u2192 514de5e8-c6e5-44e3-ad67-27f371309ab4","owningType \u2192 514de5e8-c6e5-44e3-ad67-27f371309ab4",null,"owningRelationship \u2192 174f3a40-1791-4007-a771-c98522358438","owningRelationship \u2192 174f3a40-1791-4007-a771-c98522358438",null,"result \u2192 c140d99e-241e-4f87-bc20-1df576e1e87f","result \u2192 c140d99e-241e-4f87-bc20-1df576e1e87f",null,"ownedMemberParameter \u2192 79f3ba46-4b9c-4248-910c-464649f9a2d0","ownedMemberParameter \u2192 79f3ba46-4b9c-4248-910c-464649f9a2d0",null,"type \u2192 1f505b70-008f-4d9f-8662-e43247298790","type \u2192 1f505b70-008f-4d9f-8662-e43247298790",null,"owningNamespace \u2192 c603c99d-0001-453b-98a7-853c7fa6e8a1","owningNamespace \u2192 c603c99d-0001-453b-98a7-853c7fa6e8a1",null,"owningRelationship \u2192 5a643421-dc69-40f4-a1fa-1fad6fd5e827","owningRelationship \u2192 5a643421-dc69-40f4-a1fa-1fad6fd5e827",null,"referent \u2192 9b768b3a-8afd-4eb5-b840-c76c9d0495cc","referent \u2192 9b768b3a-8afd-4eb5-b840-c76c9d0495cc",null,"result \u2192 3c88341d-b1fa-4baf-aba7-f50984718f62","result \u2192 3c88341d-b1fa-4baf-aba7-f50984718f62",null,"owningType \u2192 1f505b70-008f-4d9f-8662-e43247298790","owningType \u2192 1f505b70-008f-4d9f-8662-e43247298790",null,"owningRelationship \u2192 4d7bea3e-6368-48ad-b58c-4cea0b84eae5","owningRelationship \u2192 4d7bea3e-6368-48ad-b58c-4cea0b84eae5",null,"owningRelatedElement \u2192 c603c99d-0001-453b-98a7-853c7fa6e8a1","owningRelatedElement \u2192 c603c99d-0001-453b-98a7-853c7fa6e8a1",null,"value \u2192 1c289641-44bd-44a2-852e-1359a8ad3dbc","value \u2192 1c289641-44bd-44a2-852e-1359a8ad3dbc",null,"multiplicity \u2192 ee7bd99a-5a99-4904-9af8-f7741c301b7b","multiplicity \u2192 ee7bd99a-5a99-4904-9af8-f7741c301b7b",null,"owningType \u2192 1c289641-44bd-44a2-852e-1359a8ad3dbc","owningType \u2192 1c289641-44bd-44a2-852e-1359a8ad3dbc",null,"owningRelationship \u2192 78e42437-720a-4636-b653-1369c87406c9","owningRelationship \u2192 78e42437-720a-4636-b653-1369c87406c9",null,"owningNamespace \u2192 6652699d-14c3-49a6-add7-173af88882a9","owningNamespace \u2192 6652699d-14c3-49a6-add7-173af88882a9",null,"owningRelationship \u2192 870b0f63-91b3-4768-8176-4e88a60f7684","owningRelationship \u2192 870b0f63-91b3-4768-8176-4e88a60f7684",null,"referent \u2192 d1305691-d72d-485c-b957-392a140cdba9","referent \u2192 d1305691-d72d-485c-b957-392a140cdba9",null,"result \u2192 eaf6fbf0-c7bf-459c-9073-a1d15cc4877f","result \u2192 eaf6fbf0-c7bf-459c-9073-a1d15cc4877f",null,"owningType \u2192 f716979c-3081-4119-b309-f3a28b435e3d","owningType \u2192 f716979c-3081-4119-b309-f3a28b435e3d",null,"owningRelationship \u2192 9879b7dd-a145-4b22-855a- ...

# %% [markdown]
# # Link to the interactive plot on nbviewer
# https://nbviewer.org/github/avianinc/sysml_tracer/blob/c9af442241299d300d64cf4854b04e0b0a665132/sysml_graph.ipynb
