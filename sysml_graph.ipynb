# %%
import json
import plotly.graph_objects as go
import networkx as nx
from plotly.offline import plot
import numpy as np
from IPython.display import HTML, display

# %%
# Load and parse the JSON file
with open('data/qrc.json', 'r') as json_file:
    data = json.load(json_file)

# Initialize a directed graph in networkx
G = nx.DiGraph()

# %%
# Process nodes and edges and build hover text details
node_info = {}
edge_hover_info = {}
for element in data:
    node_id = element.get('@id')
    if node_id:
        # Collect the required attributes, if present
        attributes = {
            '@type': element.get('@type', 'No Type'),
            'name': element.get('name', ''),
            'value': element.get('value', ''),
            'operator': element.get('operator', ''),
        }
        node_label = '\n'.join(f'{key}: {val}' for key, val in attributes.items() if val)
        G.add_node(node_id, label=node_label)
        # Store the full JSON data of the node for hover info
        node_info[node_id] = '<br>'.join([f'{k}: {v}' for k, v in element.items() if v])
        
    # Add edges and store connection data for hover info
    for key, value in element.items():
        if isinstance(value, dict) and value.get('@id'):
            target_id = value.get('@id')
            G.add_edge(node_id, target_id)
            edge_hover_info[(node_id, target_id)] = f'{key} → {target_id}'

# %%
# Use a layout algorithm to position the nodes
node_id_to_position = nx.spring_layout(G)

# %%
# Initialize edge trace for Plotly
edge_trace = go.Scatter(
    x=[],
    y=[],
    line=dict(width=1, color='#888'),
    hoverinfo='text',
    mode='lines',
    text=[])

# %%
# Add edge positions to the edge trace and the respective hover text
for edge in G.edges():
    x0, y0 = node_id_to_position[edge[0]]
    x1, y1 = node_id_to_position[edge[1]]
    edge_trace['x'] += (x0, x1, None)
    edge_trace['y'] += (y0, y1, None)
    edge_hover_text = edge_hover_info.get(edge, '')
    edge_trace['text'] += (edge_hover_text, edge_hover_text, None)

# %%
# Initialize node trace for Plotly
node_trace = go.Scatter(
    x=[],
    y=[],
    text=[],
    mode='markers+text',
    hovertext=[],
    hoverinfo='text',
    textposition='bottom center',
    marker=dict(
        showscale=False,
        color='LightSkyBlue',
        size=10,
        line_width=2))

# %%
# Add node positions, labels, and hover texts to the node trace
for node in G.nodes():
    x, y = node_id_to_position[node]
    node_trace['x'] += (x,)
    node_trace['y'] += (y,)
    node_trace['text'] += (G.nodes[node]['label'],)
    node_trace['hovertext'] += (node_info.get(node, ''),)

# %%
# Create the figure
fig = go.FigureWidget(data=[edge_trace, node_trace],
                layout=go.Layout(
                    title='Interactive SysMLv2 Network Graph',
                    titlefont_size=16,
                    height=800,
                    showlegend=False,
                    hovermode='closest',
                    margin=dict(b=20, l=5, r=5, t=40),
                    xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                    yaxis=dict(showgrid=False, zeroline=False, showticklabels=False)))

# %%
fig
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'text',
#               'line': {'color': '#888', 'width': 1},
#               'mode': 'lines',
#               'text': [ownedMemberFeature → bfe7bd8f-8dee-4635-b91c-9f27f685e926,
#                        ownedMemberFeature → bfe7bd8f-8dee-4635-b91c-9f27f685e926,
#                        None, ..., value → 9ce85058-1a9c-4ab3-8d73-c543bf571655,
#                        value → 9ce85058-1a9c-4ab3-8d73-c543bf571655, None],
#               'type': 'scatter',
#               'uid': 'cf2e19fa-ab97-47f9-a92f-41c3c4af9ad7',
#               'x': [0.5440872570266438, 0.6010670706859121, None, ...,
#                     0.6041848992776738, 0.6327586298899333, None],
#               'y': [-0.6710658296776066, -0.7153886242971558, None, ...,
#                     -0.8238430990176425, -0.7715741059429597, None]},
#              {'hoverinfo': 'text',
#               'hovertext': [@type: FeatureMembership<br>@id:
#                             635407dc-1fde-4315-a388-52a0fae347dd<br>elementId:
#                             635407dc-1fde-4315-a388-52a0fae347dd<br>feature:
#                             {'@id': 'bfe7bd8f-8dee-4635-b91c-
#                             9f27f685e926'}<br>memberElement: {'@id': 'bfe7bd8f-
#                             8dee-4635-b91c-9f27f685e926'}<br>memberElementId:
#                             bfe7bd8f-8dee-4635-b91c-9f27f685e926<br>memberName:
#                             range<br>membershipOwningNamespace: {'@id': 'd1305691-
#                             d72d-485c-b957-392a140cdba9'}<br>ownedMemberElement:
#                             {'@id': 'bfe7bd8f-8dee-4635-b91c-
#                             9f27f685e926'}<br>ownedMemberElementId: bfe7bd8f-8dee-
#                             4635-b91c-9f27f685e926<br>ownedMemberFeature: {'@id': '
#                             bfe7bd8f-8dee-4635-b91c-
#                             9f27f685e926'}<br>ownedMemberName:
#                             range<br>ownedRelatedElement: [{'@id': 'bfe7bd8f-8dee-
#                             4635-b91c-9f27f685e926'}]<br>owningRelatedElement:
#                             {'@id':
#                             'd1305691-d72d-485c-b957-392a140cdba9'}<br>owningType:
#                             {'@id': 'd1305691-d72d-485c-b957-
#                             392a140cdba9'}<br>relatedElement: [{'@id':
#                             'd1305691-d72d-485c-b957-392a140cdba9'}, {'@id':
#                             'bfe7bd8f-8dee-4635-b91c-9f27f685e926'}]<br>source:
#                             [{'@id':
#                             'd1305691-d72d-485c-b957-392a140cdba9'}]<br>target:
#                             [{'@id':
#                             'bfe7bd8f-8dee-4635-b91c-9f27f685e926'}]<br>type:
#                             {'@id':
#                             'd1305691-d72d-485c-b957-392a140cdba9'}<br>visibility:
#                             public, @type: ReferenceUsage<br>@id:
#                             bfe7bd8f-8dee-4635-b91c-9f27f685e926<br>declaredName:
#                             range<br>elementId:
#                             bfe7bd8f-8dee-4635-b91c-9f27f685e926<br>featuringType:
#                             [{'@id': 'd1305691-d72d-485c-b957-
#                             392a140cdba9'}]<br>isReference: True<br>isUnique:
#                             True<br>member: [{'@id':
#                             '9ce85058-1a9c-4ab3-8d73-c543bf571655'}]<br>membership:
#                             [{'@id':
#                             '6498029a-0631-4235-bbdd-69137239903e'}]<br>name:
#                             range<br>ownedElement: [{'@id': '9ce85058-1a9c-4ab3-
#                             8d73-c543bf571655'}]<br>ownedMember: [{'@id': '9ce85058
#                             -1a9c-4ab3-8d73-c543bf571655'}]<br>ownedMembership:
#                             [{'@id': '6498029a-0631-4235-bbdd-
#                             69137239903e'}]<br>ownedRelationship: [{'@id':
#                             '6498029a-0631-4235-bbdd-69137239903e'}]<br>owner:
#                             {'@id': 'd1305691-d72d-485c-b957-
#                             392a140cdba9'}<br>owningFeatureMembership: {'@id': '635
#                             407dc-1fde-4315-a388-
#                             52a0fae347dd'}<br>owningMembership: {'@id': '635407dc-
#                             1fde-4315-a388-52a0fae347dd'}<br>owningNamespace:
#                             {'@id': 'd1305691-d72d-485c-b957-
#                             392a140cdba9'}<br>owningRelationship: {'@id':
#                             '635407dc-1fde-4315-a388-52a0fae347dd'}<br>owningType:
#                             {'@id':
#                             'd1305691-d72d-485c-b957-392a140cdba9'}<br>owningUsage:
#                             {'@id': 'd1305691-d72d-485c-b957-
#                             392a140cdba9'}<br>qualifiedName:
#                             simple_constraint::uav::range, @type: PartUsage<br>@id:
#                             d1305691-d72d-485c-b957-392a140cdba9<br>declaredName:
#                             uav<br>elementId:
#                             d1305691-d72d-485c-b957-392a140cdba9<br>feature:
#                             [{'@id': 'bfe7bd8f-8dee-4635-b91c-
#                             9f27f685e926'}]<br>featureMembership: [{'@id': '635407d
#                             c-1fde-4315-a388-52a0fae347dd'}]<br>isReference:
#                             True<br>isUnique: True<br>member: [{'@id':
#                             'bfe7bd8f-8dee-4635-b91c-9f27f685e926'}]<br>membership:
#                             [{'@id':
#                             '635407dc-1fde-4315-a388-52a0fae347dd'}]<br>name:
#                             uav<br>nestedReference: [{'@id': 'bfe7bd8f-8dee-4635-
#                             b91c-9f27f685e926'}]<br>nestedUsage: [{'@id': 'bfe7bd8f
#                             -8dee-4635-b91c-9f27f685e926'}]<br>ownedElement:
#                             [{'@id': 'bfe7bd8f-8dee-4635-b91c-
#                             9f27f685e926'}]<br>ownedFeature: [{'@id': 'bfe7bd8f-
#                             8dee-4635-b91c-
#                             9f27f685e926'}]<br>ownedFeatureMembership: [{'@id': '63
#                             5407dc-1fde-4315-a388-52a0fae347dd'}]<br>ownedMember:
#                             [{'@id': 'bfe7bd8f-8dee-4635-b91c-
#                             9f27f685e926'}]<br>ownedMembership: [{'@id': '635407dc-
#                             1fde-4315-a388-52a0fae347dd'}]<br>ownedRelationship:
#                             [{'@id': '635407dc-1fde-4315-a388-
#                             52a0fae347dd'}]<br>qualifiedName:
#                             simple_constraint::uav<br>usage: [{'@id':
#                             'bfe7bd8f-8dee-4635-b91c-9f27f685e926'}], @type:
#                             Feature<br>@id:
#                             79f3ba46-4b9c-4248-910c-464649f9a2d0<br>direction:
#                             in<br>elementId:
#                             79f3ba46-4b9c-4248-910c-464649f9a2d0<br>featuringType:
#                             [{'@id':
#                             '1f505b70-008f-4d9f-8662-e43247298790'}]<br>isUnique:
#                             True<br>member: [{'@id':
#                             'f716979c-3081-4119-b309-f3a28b435e3d'}]<br>membership:
#                             [{'@id':
#                             '9fa75de9-9318-43cd-9d60-07c85e7f8127'}]<br>name:
#                             y<br>ownedElement: [{'@id': 'f716979c-3081-4119-b309-
#                             f3a28b435e3d'}]<br>ownedMember: [{'@id': 'f716979c-
#                             3081-4119-b309-f3a28b435e3d'}]<br>ownedMembership:
#                             [{'@id': '9fa75de9-9318-43cd-9d60-
#                             07c85e7f8127'}]<br>ownedRelationship: [{'@id':
#                             '9fa75de9-9318-43cd-9d60-07c85e7f8127'}]<br>owner:
#                             {'@id': '1f505b70-008f-4d9f-8662-
#                             e43247298790'}<br>owningFeatureMembership: {'@id': '997
#                             d7d4f-710b-48ba-9625-
#                             b9df7d0acb58'}<br>owningMembership: {'@id': '997d7d4f-
#                             710b-48ba-9625-b9df7d0acb58'}<br>owningNamespace:
#                             {'@id': '1f505b70-008f-4d9f-8662-
#                             e43247298790'}<br>owningRelationship: {'@id':
#                             '997d7d4f-710b-48ba-9625-b9df7d0acb58'}<br>owningType:
#                             {'@id': '1f505b70-008f-4d9f-8662-e43247298790'}, @type:
#                             OperatorExpression<br>@id:
#                             1f505b70-008f-4d9f-8662-e43247298790<br>argument:
#                             [{'@id': '1c289641-44bd-44a2-852e-1359a8ad3dbc'},
#                             {'@id': 'f716979c-3081-4119-b309-
#                             f3a28b435e3d'}]<br>directedFeature: [{'@id':
#                             'c603c99d-0001-453b-98a7-853c7fa6e8a1'}, {'@id':
#                             '79f3ba46-4b9c-4248-910c-464649f9a2d0'}, {'@id':
#                             'c140d99e-241e-4f87-bc20-1df576e1e87f'}]<br>elementId:
#                             1f505b70-008f-4d9f-8662-e43247298790<br>feature:
#                             [{'@id': 'c603c99d-0001-453b-98a7-853c7fa6e8a1'},
#                             {'@id': '79f3ba46-4b9c-4248-910c-464649f9a2d0'},
#                             {'@id': 'c140d99e-241e-4f87-bc20-
#                             1df576e1e87f'}]<br>featureMembership: [{'@id':
#                             '4d7bea3e-6368-48ad-b58c-4cea0b84eae5'}, {'@id':
#                             '997d7d4f-710b-48ba-9625-b9df7d0acb58'}, {'@id': 'a61fc
#                             c3a-f733-45a3-b0cf-1d69f3febad6'}]<br>featuringType:
#                             [{'@id':
#                             '514de5e8-c6e5-44e3-ad67-27f371309ab4'}]<br>input:
#                             [{'@id': 'c603c99d-0001-453b-98a7-853c7fa6e8a1'},
#                             {'@id':
#                             '79f3ba46-4b9c-4248-910c-464649f9a2d0'}]<br>isUnique:
#                             True<br>member: [{'@id':
#                             'c603c99d-0001-453b-98a7-853c7fa6e8a1'}, {'@id':
#                             '79f3ba46-4b9c-4248-910c-464649f9a2d0'}, {'@id':
#                             'c140d99e-241e-4f87-bc20-1df576e1e87f'}]<br>membership:
#                             [{'@id': '4d7bea3e-6368-48ad-b58c-4cea0b84eae5'},
#                             {'@id': '997d7d4f-710b-48ba-9625-b9df7d0acb58'},
#                             {'@id':
#                             'a61fcc3a-f733-45a3-b0cf-1d69f3febad6'}]<br>operator:
#                             >=<br>output: [{'@id': 'c140d99e-241e-4f87-bc20-
#                             1df576e1e87f'}]<br>ownedElement: [{'@id':
#                             'c603c99d-0001-453b-98a7-853c7fa6e8a1'}, {'@id':
#                             '79f3ba46-4b9c-4248-910c-464649f9a2d0'}, {'@id': 'c140d
#                             99e-241e-4f87-bc20-1df576e1e87f'}]<br>ownedFeature:
#                             [{'@id': 'c603c99d-0001-453b-98a7-853c7fa6e8a1'},
#                             {'@id': '79f3ba46-4b9c-4248-910c-464649f9a2d0'},
#                             {'@id': 'c140d99e-241e-4f87-bc20-
#                             1df576e1e87f'}]<br>ownedFeatureMembership: [{'@id':
#                             '4d7bea3e-6368-48ad-b58c-4cea0b84eae5'}, {'@id':
#                             '997d7d4f-710b-48ba-9625-b9df7d0acb58'}, {'@id': 'a61fc
#                             c3a-f733-45a3-b0cf-1d69f3febad6'}]<br>ownedMember:
#                             [{'@id': 'c603c99d-0001-453b-98a7-853c7fa6e8a1'},
#                             {'@id': '79f3ba46-4b9c-4248-910c-464649f9a2d0'},
#                             {'@id': 'c140d99e-241e-4f87-bc20-
#                             1df576e1e87f'}]<br>ownedMembership: [{'@id':
#                             '4d7bea3e-6368-48ad-b58c-4cea0b84eae5'}, {'@id':
#                             '997d7d4f-710b-48ba-9625-b9df7d0acb58'}, {'@id': 'a61fc
#                             c3a-f733-45a3-b0cf-
#                             1d69f3febad6'}]<br>ownedRelationship: [{'@id':
#                             '4d7bea3e-6368-48ad-b58c-4cea0b84eae5'}, {'@id':
#                             '997d7d4f-710b-48ba-9625-b9df7d0acb58'}, {'@id':
#                             'a61fcc3a-f733-45a3-b0cf-1d69f3febad6'}]<br>owner:
#                             {'@id': '514de5e8-c6e5-44e3-ad67-
#                             27f371309ab4'}<br>owningFeatureMembership: {'@id': '174
#                             f3a40-1791-4007-a771-
#                             c98522358438'}<br>owningMembership: {'@id': '174f3a40-
#                             1791-4007-a771-c98522358438'}<br>owningNamespace:
#                             {'@id': '514de5e8-c6e5-44e3-ad67-
#                             27f371309ab4'}<br>owningRelationship: {'@id':
#                             '174f3a40-1791-4007-a771-c98522358438'}<br>owningType:
#                             {'@id':
#                             '514de5e8-c6e5-44e3-ad67-27f371309ab4'}<br>parameter:
#                             [{'@id': 'c603c99d-0001-453b-98a7-853c7fa6e8a1'},
#                             {'@id': '79f3ba46-4b9c-4248-910c-464649f9a2d0'},
#                             {'@id':
#                             'c140d99e-241e-4f87-bc20-1df576e1e87f'}]<br>result:
#                             {'@id': 'c140d99e-241e-4f87-bc20-1df576e1e87f'}, @type:
#                             ParameterMembership<br>@id:
#                             997d7d4f-710b-48ba-9625-b9df7d0acb58<br>elementId:
#                             997d7d4f-710b-48ba-9625-b9df7d0acb58<br>feature:
#                             {'@id': '79f3ba46-4b9c-4248-910c-
#                             464649f9a2d0'}<br>memberElement: {'@id': '79f3ba46-
#                             4b9c-4248-910c-464649f9a2d0'}<br>memberElementId:
#                             79f3ba46-4b9c-4248-910c-464649f9a2d0<br>memberName:
#                             y<br>membershipOwningNamespace: {'@id': '1f505b70-008f-
#                             4d9f-8662-e43247298790'}<br>ownedMemberElement: {'@id':
#                             '79f3ba46-4b9c-4248-910c-
#                             464649f9a2d0'}<br>ownedMemberElementId: 79f3ba46-4b9c-
#                             4248-910c-464649f9a2d0<br>ownedMemberFeature: {'@id': '
#                             79f3ba46-4b9c-4248-910c-
#                             464649f9a2d0'}<br>ownedMemberName:
#                             y<br>ownedMemberParameter: {'@id': '79f3ba46-4b9c-4248-
#                             910c-464649f9a2d0'}<br>ownedRelatedElement: [{'@id': '7
#                             9f3ba46-4b9c-4248-910c-
#                             464649f9a2d0'}]<br>owningRelatedElement: {'@id':
#                             '1f505b70-008f-4d9f-8662-e43247298790'}<br>owningType:
#                             {'@id': '1f505b70-008f-4d9f-8662-
#                             e43247298790'}<br>relatedElement: [{'@id':
#                             '1f505b70-008f-4d9f-8662-e43247298790'}, {'@id':
#                             '79f3ba46-4b9c-4248-910c-464649f9a2d0'}]<br>source:
#                             [{'@id':
#                             '1f505b70-008f-4d9f-8662-e43247298790'}]<br>target:
#                             [{'@id':
#                             '79f3ba46-4b9c-4248-910c-464649f9a2d0'}]<br>type:
#                             {'@id':
#                             '1f505b70-008f-4d9f-8662-e43247298790'}<br>visibility:
#                             private, @type: FeatureReferenceExpression<br>@id: 1c28
#                             9641-44bd-44a2-852e-1359a8ad3dbc<br>directedFeature:
#                             [{'@id': '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}]<br>elementId:
#                             1c289641-44bd-44a2-852e-1359a8ad3dbc<br>feature:
#                             [{'@id': '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}]<br>featureMembership: [{'@id': '78
#                             e42437-720a-4636-b653-1369c87406c9'}]<br>featuringType:
#                             [{'@id':
#                             '1f505b70-008f-4d9f-8662-e43247298790'}]<br>isUnique:
#                             True<br>member: [{'@id':
#                             '9b768b3a-8afd-4eb5-b840-c76c9d0495cc'}, {'@id':
#                             '3c88341d-b1fa-4baf-aba7-f50984718f62'}]<br>membership:
#                             [{'@id': '6f6e469d-7dd3-4361-9def-a37b648f60e3'},
#                             {'@id':
#                             '78e42437-720a-4636-b653-1369c87406c9'}]<br>output:
#                             [{'@id': '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}]<br>ownedElement: [{'@id':
#                             '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}]<br>ownedFeature: [{'@id':
#                             '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}]<br>ownedFeatureMembership:
#                             [{'@id': '78e42437-720a-4636-b653-
#                             1369c87406c9'}]<br>ownedMember: [{'@id':
#                             '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}]<br>ownedMembership: [{'@id':
#                             '6f6e469d-7dd3-4361-9def-a37b648f60e3'}, {'@id': '78e42
#                             437-720a-4636-b653-
#                             1369c87406c9'}]<br>ownedRelationship: [{'@id':
#                             '6f6e469d-7dd3-4361-9def-a37b648f60e3'}, {'@id':
#                             '78e42437-720a-4636-b653-1369c87406c9'}]<br>owner:
#                             {'@id': 'c603c99d-0001-453b-98a7-
#                             853c7fa6e8a1'}<br>owningMembership: {'@id': '5a643421-
#                             dc69-40f4-a1fa-1fad6fd5e827'}<br>owningNamespace:
#                             {'@id': 'c603c99d-0001-453b-98a7-
#                             853c7fa6e8a1'}<br>owningRelationship: {'@id':
#                             '5a643421-dc69-40f4-a1fa-1fad6fd5e827'}<br>parameter:
#                             [{'@id': '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}]<br>referent: {'@id':
#                             '9b768b3a-8afd-4eb5-b840-c76c9d0495cc'}<br>result:
#                             {'@id': '3c88341d-b1fa-4baf-aba7-f50984718f62'}, @type:
#                             Feature<br>@id:
#                             c603c99d-0001-453b-98a7-853c7fa6e8a1<br>direction:
#                             in<br>elementId:
#                             c603c99d-0001-453b-98a7-853c7fa6e8a1<br>featuringType:
#                             [{'@id':
#                             '1f505b70-008f-4d9f-8662-e43247298790'}]<br>isUnique:
#                             True<br>member: [{'@id':
#                             '1c289641-44bd-44a2-852e-1359a8ad3dbc'}]<br>membership:
#                             [{'@id':
#                             '5a643421-dc69-40f4-a1fa-1fad6fd5e827'}]<br>name:
#                             x<br>ownedElement: [{'@id': '1c289641-44bd-44a2-852e-
#                             1359a8ad3dbc'}]<br>ownedMember: [{'@id': '1c289641-
#                             44bd-44a2-852e-1359a8ad3dbc'}]<br>ownedMembership:
#                             [{'@id': '5a643421-dc69-40f4-a1fa-
#                             1fad6fd5e827'}]<br>ownedRelationship: [{'@id':
#                             '5a643421-dc69-40f4-a1fa-1fad6fd5e827'}]<br>owner:
#                             {'@id': '1f505b70-008f-4d9f-8662-
#                             e43247298790'}<br>owningFeatureMembership: {'@id': '4d7
#                             bea3e-6368-48ad-b58c-
#                             4cea0b84eae5'}<br>owningMembership: {'@id': '4d7bea3e-
#                             6368-48ad-b58c-4cea0b84eae5'}<br>owningNamespace:
#                             {'@id': '1f505b70-008f-4d9f-8662-
#                             e43247298790'}<br>owningRelationship: {'@id':
#                             '4d7bea3e-6368-48ad-b58c-4cea0b84eae5'}<br>owningType:
#                             {'@id': '1f505b70-008f-4d9f-8662-e43247298790'}, @type:
#                             FeatureValue<br>@id:
#                             5a643421-dc69-40f4-a1fa-1fad6fd5e827<br>elementId: 5a64
#                             3421-dc69-40f4-a1fa-1fad6fd5e827<br>featureWithValue:
#                             {'@id': 'c603c99d-0001-453b-98a7-
#                             853c7fa6e8a1'}<br>memberElement: {'@id': '1c289641-
#                             44bd-44a2-852e-1359a8ad3dbc'}<br>memberElementId: 1c289
#                             641-44bd-44a2-852e-
#                             1359a8ad3dbc<br>membershipOwningNamespace: {'@id': 'c60
#                             3c99d-0001-453b-98a7-
#                             853c7fa6e8a1'}<br>ownedMemberElement: {'@id': '1c289641
#                             -44bd-44a2-852e-1359a8ad3dbc'}<br>ownedMemberElementId:
#                             1c289641-44bd-44a2-852e-
#                             1359a8ad3dbc<br>ownedRelatedElement: [{'@id': '1c289641
#                             -44bd-44a2-852e-
#                             1359a8ad3dbc'}]<br>owningRelatedElement: {'@id': 'c603c
#                             99d-0001-453b-98a7-853c7fa6e8a1'}<br>relatedElement:
#                             [{'@id': 'c603c99d-0001-453b-98a7-853c7fa6e8a1'},
#                             {'@id':
#                             '1c289641-44bd-44a2-852e-1359a8ad3dbc'}]<br>source:
#                             [{'@id':
#                             'c603c99d-0001-453b-98a7-853c7fa6e8a1'}]<br>target:
#                             [{'@id':
#                             '1c289641-44bd-44a2-852e-1359a8ad3dbc'}]<br>value:
#                             {'@id':
#                             '1c289641-44bd-44a2-852e-1359a8ad3dbc'}<br>visibility:
#                             public, @type: AttributeUsage<br>@id:
#                             9b768b3a-8afd-4eb5-b840-c76c9d0495cc<br>declaredName:
#                             measuredRange<br>documentation: [{'@id':
#                             '18603c4b-fea7-4d78-92af-99b0489a9cf2'}]<br>elementId:
#                             9b768b3a-8afd-4eb5-b840-c76c9d0495cc<br>isReference:
#                             True<br>isUnique: True<br>member: [{'@id':
#                             '18603c4b-fea7-4d78-92af-99b0489a9cf2'}, {'@id':
#                             'ee7bd99a-5a99-4904-9af8-f7741c301b7b'}]<br>membership:
#                             [{'@id': '5aeb175f-5cc1-47b5-95ad-4313cde6e57f'},
#                             {'@id': 'b91f3d8a-b746-4256-906c-
#                             023263e73f11'}]<br>multiplicity: {'@id':
#                             'ee7bd99a-5a99-4904-9af8-f7741c301b7b'}<br>name:
#                             measuredRange<br>ownedElement: [{'@id':
#                             '18603c4b-fea7-4d78-92af-99b0489a9cf2'}, {'@id': 'ee7bd
#                             99a-5a99-4904-9af8-f7741c301b7b'}]<br>ownedMember:
#                             [{'@id': '18603c4b-fea7-4d78-92af-99b0489a9cf2'},
#                             {'@id': 'ee7bd99a-5a99-4904-9af8-
#                             f7741c301b7b'}]<br>ownedMembership: [{'@id':
#                             '5aeb175f-5cc1-47b5-95ad-4313cde6e57f'}, {'@id': 'b91f3
#                             d8a-b746-4256-906c-
#                             023263e73f11'}]<br>ownedRelationship: [{'@id':
#                             '5aeb175f-5cc1-47b5-95ad-4313cde6e57f'}, {'@id': 'b91f3
#                             d8a-b746-4256-906c-023263e73f11'}]<br>qualifiedName:
#                             simple_constraint::UAV_Range::measuredRange, @type:
#                             Feature<br>@id: 3c88341d-b1fa-4baf-
#                             aba7-f50984718f62<br>direction: out<br>elementId:
#                             3c88341d-b1fa-4baf-aba7-f50984718f62<br>featuringType:
#                             [{'@id': '1c289641-44bd-44a2-852e-
#                             1359a8ad3dbc'}]<br>inheritedMembership: [{'@id':
#                             '5aeb175f-5cc1-47b5-95ad-4313cde6e57f'}, {'@id':
#                             'b91f3d8a-b746-4256-906c-023263e73f11'}]<br>isUnique:
#                             True<br>member: [{'@id':
#                             '18603c4b-fea7-4d78-92af-99b0489a9cf2'}, {'@id':
#                             'ee7bd99a-5a99-4904-9af8-f7741c301b7b'}]<br>membership:
#                             [{'@id': '5aeb175f-5cc1-47b5-95ad-4313cde6e57f'},
#                             {'@id':
#                             'b91f3d8a-b746-4256-906c-023263e73f11'}]<br>name:
#                             result<br>owner: {'@id': '1c289641-44bd-44a2-852e-
#                             1359a8ad3dbc'}<br>owningFeatureMembership: {'@id': '78e
#                             42437-720a-4636-b653-
#                             1369c87406c9'}<br>owningMembership: {'@id': '78e42437-
#                             720a-4636-b653-1369c87406c9'}<br>owningNamespace:
#                             {'@id': '1c289641-44bd-44a2-852e-
#                             1359a8ad3dbc'}<br>owningRelationship: {'@id':
#                             '78e42437-720a-4636-b653-1369c87406c9'}<br>owningType:
#                             {'@id': '1c289641-44bd-44a2-852e-1359a8ad3dbc'}, @type:
#                             FeatureReferenceExpression<br>@id: 03bc163d-47c3-40fa-
#                             bc57-52059aea2b57<br>directedFeature: [{'@id':
#                             'eaf6fbf0-c7bf-459c-9073-a1d15cc4877f'}]<br>elementId:
#                             03bc163d-47c3-40fa-bc57-52059aea2b57<br>feature:
#                             [{'@id': 'eaf6fbf0-c7bf-459c-9073-
#                             a1d15cc4877f'}]<br>featureMembership: [{'@id': 'eb9e8f4
#                             3-d99b-43c9-b0c5-0548a0fea344'}]<br>featuringType:
#                             [{'@id': 'f716979c-3081-4119-b309-
#                             f3a28b435e3d'}]<br>isModelLevelEvaluable:
#                             True<br>isUnique: True<br>member: [{'@id':
#                             'd1305691-d72d-485c-b957-392a140cdba9'}, {'@id':
#                             'eaf6fbf0-c7bf-459c-9073-a1d15cc4877f'}]<br>membership:
#                             [{'@id': 'a6049574-3c74-4e38-bba5-6cbc2f2e15a2'},
#                             {'@id':
#                             'eb9e8f43-d99b-43c9-b0c5-0548a0fea344'}]<br>output:
#                             [{'@id': 'eaf6fbf0-c7bf-459c-9073-
#                             a1d15cc4877f'}]<br>ownedElement: [{'@id': 'eaf6fbf0-
#                             c7bf-459c-9073-a1d15cc4877f'}]<br>ownedFeature:
#                             [{'@id': 'eaf6fbf0-c7bf-459c-9073-
#                             a1d15cc4877f'}]<br>ownedFeatureMembership: [{'@id': 'eb
#                             9e8f43-d99b-43c9-b0c5-0548a0fea344'}]<br>ownedMember:
#                             [{'@id': 'eaf6fbf0-c7bf-459c-9073-
#                             a1d15cc4877f'}]<br>ownedMembership: [{'@id':
#                             'a6049574-3c74-4e38-bba5-6cbc2f2e15a2'}, {'@id': 'eb9e8
#                             f43-d99b-43c9-b0c5-
#                             0548a0fea344'}]<br>ownedRelationship: [{'@id':
#                             'a6049574-3c74-4e38-bba5-6cbc2f2e15a2'}, {'@id':
#                             'eb9e8f43-d99b-43c9-b0c5-0548a0fea344'}]<br>owner:
#                             {'@id': '6652699d-14c3-49a6-add7-
#                             173af88882a9'}<br>owningMembership: {'@id': '870b0f63-
#                             91b3-4768-8176-4e88a60f7684'}<br>owningNamespace:
#                             {'@id': '6652699d-14c3-49a6-add7-
#                             173af88882a9'}<br>owningRelationship: {'@id':
#                             '870b0f63-91b3-4768-8176-4e88a60f7684'}<br>parameter:
#                             [{'@id':
#                             'eaf6fbf0-c7bf-459c-9073-a1d15cc4877f'}]<br>referent:
#                             {'@id':
#                             'd1305691-d72d-485c-b957-392a140cdba9'}<br>result:
#                             {'@id': 'eaf6fbf0-c7bf-459c-9073-a1d15cc4877f'}, @type:
#                             Feature<br>@id:
#                             6652699d-14c3-49a6-add7-173af88882a9<br>direction:
#                             in<br>elementId:
#                             6652699d-14c3-49a6-add7-173af88882a9<br>feature:
#                             [{'@id': 'a7757938-905c-47e7-bba8-
#                             a0237288fef5'}]<br>featureMembership: [{'@id': 'f41afb7
#                             e-9520-48c2-80d8-c57644280345'}]<br>featuringType:
#                             [{'@id':
#                             'f716979c-3081-4119-b309-f3a28b435e3d'}]<br>isUnique:
#                             True<br>member: [{'@id': '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}, {'@id':
#                             'a7757938-905c-47e7-bba8-a0237288fef5'}]<br>membership:
#                             [{'@id': '870b0f63-91b3-4768-8176-4e88a60f7684'},
#                             {'@id':
#                             'f41afb7e-9520-48c2-80d8-c57644280345'}]<br>name:
#                             source<br>ownedElement: [{'@id': '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}, {'@id': 'a7757938-905c-47e7-bba8-
#                             a0237288fef5'}]<br>ownedFeature: [{'@id': 'a7757938-
#                             905c-47e7-bba8-
#                             a0237288fef5'}]<br>ownedFeatureMembership: [{'@id': 'f4
#                             1afb7e-9520-48c2-80d8-c57644280345'}]<br>ownedMember:
#                             [{'@id': '03bc163d-47c3-40fa-bc57-52059aea2b57'},
#                             {'@id': 'a7757938-905c-47e7-bba8-
#                             a0237288fef5'}]<br>ownedMembership: [{'@id':
#                             '870b0f63-91b3-4768-8176-4e88a60f7684'}, {'@id': 'f41af
#                             b7e-9520-48c2-80d8-
#                             c57644280345'}]<br>ownedRelationship: [{'@id':
#                             '870b0f63-91b3-4768-8176-4e88a60f7684'}, {'@id':
#                             'f41afb7e-9520-48c2-80d8-c57644280345'}]<br>owner:
#                             {'@id': 'f716979c-3081-4119-b309-
#                             f3a28b435e3d'}<br>owningFeatureMembership: {'@id': '987
#                             9b7dd-a145-4b22-855a-
#                             40663b1ccca5'}<br>owningMembership: {'@id': '9879b7dd-
#                             a145-4b22-855a-40663b1ccca5'}<br>owningNamespace:
#                             {'@id': 'f716979c-3081-4119-b309-
#                             f3a28b435e3d'}<br>owningRelationship: {'@id':
#                             '9879b7dd-a145-4b22-855a-40663b1ccca5'}<br>owningType:
#                             {'@id': 'f716979c-3081-4119-b309-f3a28b435e3d'}, @type:
#                             FeatureValue<br>@id:
#                             870b0f63-91b3-4768-8176-4e88a60f7684<br>elementId: 870b
#                             0f63-91b3-4768-8176-4e88a60f7684<br>featureWithValue:
#                             {'@id': '6652699d-14c3-49a6-add7-
#                             173af88882a9'}<br>memberElement: {'@id':
#                             '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}<br>memberElementId:
#                             03bc163d-47c3-40fa-
#                             bc57-52059aea2b57<br>membershipOwningNamespace: {'@id':
#                             '6652699d-14c3-49a6-add7-
#                             173af88882a9'}<br>ownedMemberElement: {'@id':
#                             '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}<br>ownedMemberElementId:
#                             03bc163d-47c3-40fa-
#                             bc57-52059aea2b57<br>ownedRelatedElement: [{'@id':
#                             '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}]<br>owningRelatedElement: {'@id': '
#                             6652699d-14c3-49a6-add7-
#                             173af88882a9'}<br>relatedElement: [{'@id':
#                             '6652699d-14c3-49a6-add7-173af88882a9'}, {'@id':
#                             '03bc163d-47c3-40fa-bc57-52059aea2b57'}]<br>source:
#                             [{'@id':
#                             '6652699d-14c3-49a6-add7-173af88882a9'}]<br>target:
#                             [{'@id': '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}]<br>value: {'@id':
#                             '03bc163d-47c3-40fa-bc57-52059aea2b57'}<br>visibility:
#                             public, @type: Feature<br>@id:
#                             eaf6fbf0-c7bf-459c-9073-a1d15cc4877f<br>direction:
#                             out<br>elementId:
#                             eaf6fbf0-c7bf-459c-9073-a1d15cc4877f<br>feature:
#                             [{'@id': 'bfe7bd8f-8dee-4635-b91c-
#                             9f27f685e926'}]<br>featureMembership: [{'@id': '635407d
#                             c-1fde-4315-a388-52a0fae347dd'}]<br>featuringType:
#                             [{'@id': '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}]<br>inheritedFeature: [{'@id': 'bfe
#                             7bd8f-8dee-4635-b91c-
#                             9f27f685e926'}]<br>inheritedMembership: [{'@id':
#                             '635407dc-1fde-4315-a388-52a0fae347dd'}]<br>isUnique:
#                             True<br>member: [{'@id':
#                             'bfe7bd8f-8dee-4635-b91c-9f27f685e926'}]<br>membership:
#                             [{'@id':
#                             '635407dc-1fde-4315-a388-52a0fae347dd'}]<br>name:
#                             result<br>owner: {'@id': '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}<br>owningFeatureMembership: {'@id':
#                             'eb9e8f43-d99b-43c9-b0c5-
#                             0548a0fea344'}<br>owningMembership: {'@id': 'eb9e8f43-
#                             d99b-43c9-b0c5-0548a0fea344'}<br>owningNamespace:
#                             {'@id': '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}<br>owningRelationship: {'@id':
#                             'eb9e8f43-d99b-43c9-b0c5-0548a0fea344'}<br>owningType:
#                             {'@id': '03bc163d-47c3-40fa-bc57-52059aea2b57'}, @type:
#                             Feature<br>@id:
#                             f30c14cf-29cf-4b8e-953d-ac8dd4f91ad6<br>direction:
#                             out<br>elementId:
#                             f30c14cf-29cf-4b8e-953d-ac8dd4f91ad6<br>featuringType:
#                             [{'@id': 'f716979c-3081-4119-b309-
#                             f3a28b435e3d'}]<br>inheritedMembership: [{'@id':
#                             '6498029a-0631-4235-bbdd-69137239903e'}]<br>isUnique:
#                             True<br>member: [{'@id':
#                             '9ce85058-1a9c-4ab3-8d73-c543bf571655'}]<br>membership:
#                             [{'@id':
#                             '6498029a-0631-4235-bbdd-69137239903e'}]<br>name:
#                             result<br>owner: {'@id': 'f716979c-3081-4119-b309-
#                             f3a28b435e3d'}<br>owningFeatureMembership: {'@id': '032
#                             ced76-5814-4762-a833-
#                             9bf7efb85e7e'}<br>owningMembership: {'@id': '032ced76-
#                             5814-4762-a833-9bf7efb85e7e'}<br>owningNamespace:
#                             {'@id': 'f716979c-3081-4119-b309-
#                             f3a28b435e3d'}<br>owningRelationship: {'@id':
#                             '032ced76-5814-4762-a833-9bf7efb85e7e'}<br>owningType:
#                             {'@id': 'f716979c-3081-4119-b309-f3a28b435e3d'}, @type:
#                             FeatureChainExpression<br>@id:
#                             f716979c-3081-4119-b309-f3a28b435e3d<br>argument:
#                             [{'@id': '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}]<br>directedFeature: [{'@id':
#                             '6652699d-14c3-49a6-add7-173af88882a9'}, {'@id':
#                             'f30c14cf-29cf-4b8e-953d-ac8dd4f91ad6'}]<br>elementId:
#                             f716979c-3081-4119-b309-f3a28b435e3d<br>feature:
#                             [{'@id': '6652699d-14c3-49a6-add7-173af88882a9'},
#                             {'@id': 'f30c14cf-29cf-4b8e-953d-
#                             ac8dd4f91ad6'}]<br>featureMembership: [{'@id':
#                             '9879b7dd-a145-4b22-855a-40663b1ccca5'}, {'@id': '032ce
#                             d76-5814-4762-a833-9bf7efb85e7e'}]<br>featuringType:
#                             [{'@id':
#                             '1f505b70-008f-4d9f-8662-e43247298790'}]<br>input:
#                             [{'@id': '6652699d-14c3-49a6-add7-
#                             173af88882a9'}]<br>isModelLevelEvaluable:
#                             True<br>isUnique: True<br>member: [{'@id':
#                             '6652699d-14c3-49a6-add7-173af88882a9'}, {'@id':
#                             'bfe7bd8f-8dee-4635-b91c-9f27f685e926'}, {'@id':
#                             'f30c14cf-29cf-4b8e-953d-ac8dd4f91ad6'}]<br>membership:
#                             [{'@id': '9879b7dd-a145-4b22-855a-40663b1ccca5'},
#                             {'@id': '9ff4e6c4-0771-43f6-b6d2-604a428cab82'},
#                             {'@id':
#                             '032ced76-5814-4762-a833-9bf7efb85e7e'}]<br>operator:
#                             .<br>output: [{'@id': 'f30c14cf-29cf-4b8e-953d-
#                             ac8dd4f91ad6'}]<br>ownedElement: [{'@id':
#                             '6652699d-14c3-49a6-add7-173af88882a9'}, {'@id': 'f30c1
#                             4cf-29cf-4b8e-953d-ac8dd4f91ad6'}]<br>ownedFeature:
#                             [{'@id': '6652699d-14c3-49a6-add7-173af88882a9'},
#                             {'@id': 'f30c14cf-29cf-4b8e-953d-
#                             ac8dd4f91ad6'}]<br>ownedFeatureMembership: [{'@id':
#                             '9879b7dd-a145-4b22-855a-40663b1ccca5'}, {'@id': '032ce
#                             d76-5814-4762-a833-9bf7efb85e7e'}]<br>ownedMember:
#                             [{'@id': '6652699d-14c3-49a6-add7-173af88882a9'},
#                             {'@id': 'f30c14cf-29cf-4b8e-953d-
#                             ac8dd4f91ad6'}]<br>ownedMembership: [{'@id':
#                             '9879b7dd-a145-4b22-855a-40663b1ccca5'}, {'@id':
#                             '9ff4e6c4-0771-43f6-b6d2-604a428cab82'}, {'@id': '032ce
#                             d76-5814-4762-a833-
#                             9bf7efb85e7e'}]<br>ownedRelationship: [{'@id':
#                             '9879b7dd-a145-4b22-855a-40663b1ccca5'}, {'@id':
#                             '9ff4e6c4-0771-43f6-b6d2-604a428cab82'}, {'@id':
#                             '032ced76-5814-4762-a833-9bf7efb85e7e'}]<br>owner:
#                             {'@id': '79f3ba46-4b9c-4248-910c-
#                             464649f9a2d0'}<br>owningMembership: {'@id': '9fa75de9-
#                             9318-43cd-9d60-07c85e7f8127'}<br>owningNamespace:
#                             {'@id': '79f3ba46-4b9c-4248-910c-
#                             464649f9a2d0'}<br>owningRelationship: {'@id':
#                             '9fa75de9-9318-43cd-9d60-07c85e7f8127'}<br>parameter:
#                             [{'@id': '6652699d-14c3-49a6-add7-173af88882a9'},
#                             {'@id':
#                             'f30c14cf-29cf-4b8e-953d-ac8dd4f91ad6'}]<br>result:
#                             {'@id': 'f30c14cf-29cf-4b8e-953d-
#                             ac8dd4f91ad6'}<br>targetFeature: {'@id':
#                             'bfe7bd8f-8dee-4635-b91c-9f27f685e926'}, @type:
#                             ReturnParameterMembership<br>@id:
#                             032ced76-5814-4762-a833-9bf7efb85e7e<br>elementId:
#                             032ced76-5814-4762-a833-9bf7efb85e7e<br>feature:
#                             {'@id': 'f30c14cf-29cf-4b8e-953d-
#                             ac8dd4f91ad6'}<br>memberElement: {'@id': 'f30c14cf-
#                             29cf-4b8e-953d-ac8dd4f91ad6'}<br>memberElementId:
#                             f30c14cf-29cf-4b8e-953d-ac8dd4f91ad6<br>memberName:
#                             result<br>membershipOwningNamespace: {'@id': 'f716979c-
#                             3081-4119-b309-f3a28b435e3d'}<br>ownedMemberElement:
#                             {'@id': 'f30c14cf-29cf-4b8e-953d-
#                             ac8dd4f91ad6'}<br>ownedMemberElementId: f30c14cf-29cf-
#                             4b8e-953d-ac8dd4f91ad6<br>ownedMemberFeature: {'@id': '
#                             f30c14cf-29cf-4b8e-953d-
#                             ac8dd4f91ad6'}<br>ownedMemberName:
#                             result<br>ownedMemberParameter: {'@id': 'f30c14cf-29cf-
#                             4b8e-953d-ac8dd4f91ad6'}<br>ownedRelatedElement:
#                             [{'@id': 'f30c14cf-29cf-4b8e-953d-
#                             ac8dd4f91ad6'}]<br>owningRelatedElement: {'@id':
#                             'f716979c-3081-4119-b309-f3a28b435e3d'}<br>owningType:
#                             {'@id': 'f716979c-3081-4119-b309-
#                             f3a28b435e3d'}<br>relatedElement: [{'@id':
#                             'f716979c-3081-4119-b309-f3a28b435e3d'}, {'@id':
#                             'f30c14cf-29cf-4b8e-953d-ac8dd4f91ad6'}]<br>source:
#                             [{'@id':
#                             'f716979c-3081-4119-b309-f3a28b435e3d'}]<br>target:
#                             [{'@id':
#                             'f30c14cf-29cf-4b8e-953d-ac8dd4f91ad6'}]<br>type:
#                             {'@id':
#                             'f716979c-3081-4119-b309-f3a28b435e3d'}<br>visibility:
#                             public, @type: ReturnParameterMembership<br>@id:
#                             eb9e8f43-d99b-43c9-b0c5-0548a0fea344<br>elementId:
#                             eb9e8f43-d99b-43c9-b0c5-0548a0fea344<br>feature:
#                             {'@id': 'eaf6fbf0-c7bf-459c-9073-
#                             a1d15cc4877f'}<br>memberElement: {'@id': 'eaf6fbf0-
#                             c7bf-459c-9073-a1d15cc4877f'}<br>memberElementId:
#                             eaf6fbf0-c7bf-459c-9073-a1d15cc4877f<br>memberName:
#                             result<br>membershipOwningNamespace: {'@id':
#                             '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}<br>ownedMemberElement: {'@id': 'eaf
#                             6fbf0-c7bf-459c-9073-
#                             a1d15cc4877f'}<br>ownedMemberElementId: eaf6fbf0-c7bf-
#                             459c-9073-a1d15cc4877f<br>ownedMemberFeature: {'@id': '
#                             eaf6fbf0-c7bf-459c-9073-
#                             a1d15cc4877f'}<br>ownedMemberName:
#                             result<br>ownedMemberParameter: {'@id': 'eaf6fbf0-c7bf-
#                             459c-9073-a1d15cc4877f'}<br>ownedRelatedElement:
#                             [{'@id': 'eaf6fbf0-c7bf-459c-9073-
#                             a1d15cc4877f'}]<br>owningRelatedElement: {'@id':
#                             '03bc163d-47c3-40fa-bc57-52059aea2b57'}<br>owningType:
#                             {'@id': '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}<br>relatedElement: [{'@id':
#                             '03bc163d-47c3-40fa-bc57-52059aea2b57'}, {'@id':
#                             'eaf6fbf0-c7bf-459c-9073-a1d15cc4877f'}]<br>source:
#                             [{'@id': '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}]<br>target: [{'@id':
#                             'eaf6fbf0-c7bf-459c-9073-a1d15cc4877f'}]<br>type:
#                             {'@id': '03bc163d-47c3-40fa-
#                             bc57-52059aea2b57'}<br>visibility: public, @type:
#                             FeatureValue<br>@id:
#                             9fa75de9-9318-43cd-9d60-07c85e7f8127<br>elementId: 9fa7
#                             5de9-9318-43cd-9d60-07c85e7f8127<br>featureWithValue:
#                             {'@id': '79f3ba46-4b9c-4248-910c-
#                             464649f9a2d0'}<br>memberElement: {'@id': 'f716979c-
#                             3081-4119-b309-f3a28b435e3d'}<br>memberElementId: f7169
#                             79c-3081-4119-b309-
#                             f3a28b435e3d<br>membershipOwningNamespace: {'@id': '79f
#                             3ba46-4b9c-4248-910c-
#                             464649f9a2d0'}<br>ownedMemberElement: {'@id': 'f716979c
#                             -3081-4119-b309-f3a28b435e3d'}<br>ownedMemberElementId:
#                             f716979c-3081-4119-b309-
#                             f3a28b435e3d<br>ownedRelatedElement: [{'@id': 'f716979c
#                             -3081-4119-b309-
#                             f3a28b435e3d'}]<br>owningRelatedElement: {'@id': '79f3b
#                             a46-4b9c-4248-910c-464649f9a2d0'}<br>relatedElement:
#                             [{'@id': '79f3ba46-4b9c-4248-910c-464649f9a2d0'},
#                             {'@id':
#                             'f716979c-3081-4119-b309-f3a28b435e3d'}]<br>source:
#                             [{'@id':
#                             '79f3ba46-4b9c-4248-910c-464649f9a2d0'}]<br>target:
#                             [{'@id':
#                             'f716979c-3081-4119-b309-f3a28b435e3d'}]<br>value:
#                             {'@id':
#                             'f716979c-3081-4119-b309-f3a28b435e3d'}<br>visibility:
#                             public, @type: ParameterMembership<br>@id:
#                             4d7bea3e-6368-48ad-b58c-4cea0b84eae5<br>elementId:
#                             4d7bea3e-6368-48ad-b58c-4cea0b84eae5<br>feature:
#                             {'@id': 'c603c99d-0001-453b-98a7-
#                             853c7fa6e8a1'}<br>memberElement: {'@id': 'c603c99d-
#                             0001-453b-98a7-853c7fa6e8a1'}<br>memberElementId:
#                             c603c99d-0001-453b-98a7-853c7fa6e8a1<br>memberName:
#                             x<br>membershipOwningNamespace: {'@id': '1f505b70-008f-
#                             4d9f-8662-e43247298790'}<br>ownedMemberElement: {'@id':
#                             'c603c99d-0001-453b-98a7-
#                             853c7fa6e8a1'}<br>ownedMemberElementId: c603c99d-0001-
#                             453b-98a7-853c7fa6e8a1<br>ownedMemberFeature: {'@id': '
#                             c603c99d-0001-453b-98a7-
#                             853c7fa6e8a1'}<br>ownedMemberName:
#                             x<br>ownedMemberParameter: {'@id': 'c603c99d-0001-453b-
#                             98a7-853c7fa6e8a1'}<br>ownedRelatedElement: [{'@id': 'c
#                             603c99d-0001-453b-98a7-
#                             853c7fa6e8a1'}]<br>owningRelatedElement: {'@id':
#                             '1f505b70-008f-4d9f-8662-e43247298790'}<br>owningType:
#                             {'@id': '1f505b70-008f-4d9f-8662-
#                             e43247298790'}<br>relatedElement: [{'@id':
#                             '1f505b70-008f-4d9f-8662-e43247298790'}, {'@id':
#                             'c603c99d-0001-453b-98a7-853c7fa6e8a1'}]<br>source:
#                             [{'@id':
#                             '1f505b70-008f-4d9f-8662-e43247298790'}]<br>target:
#                             [{'@id':
#                             'c603c99d-0001-453b-98a7-853c7fa6e8a1'}]<br>type:
#                             {'@id':
#                             '1f505b70-008f-4d9f-8662-e43247298790'}<br>visibility:
#                             private, @type: LiteralInteger<br>@id: 181d67f0-9713-
#                             4a03-98a1-03d146dec544<br>directedFeature: [{'@id':
#                             '32752c89-46f7-41bb-98fc-721fa09cbaf3'}]<br>elementId:
#                             181d67f0-9713-4a03-98a1-03d146dec544<br>feature:
#                             [{'@id': '32752c89-46f7-41bb-98fc-
#                             721fa09cbaf3'}]<br>featureMembership: [{'@id': '3c7a20d
#                             6-7c26-4f42-ae88-
#                             13b20a75cf4b'}]<br>isModelLevelEvaluable:
#                             True<br>isUnique: True<br>member: [{'@id':
#                             '32752c89-46f7-41bb-98fc-721fa09cbaf3'}]<br>membership:
#                             [{'@id':
# ...
#                             d43aa6-1874-4e92-a358-23c9f86ca774'}]<br>ownedMember:
#                             [{'@id': '82f9c8cf-
#                             ccdc-451b-bfdb-f6b30d06e8e5'}]<br>ownedMembership:
#                             [{'@id': '19d43aa6-1874-4e92-a358-
#                             23c9f86ca774'}]<br>ownedRelationship: [{'@id':
#                             '19d43aa6-1874-4e92-a358-23c9f86ca774'}]<br>owner:
#                             {'@id': 'bfe7bd8f-8dee-4635-b91c-
#                             9f27f685e926'}<br>owningMembership: {'@id': '6498029a-
#                             0631-4235-bbdd-69137239903e'}<br>owningNamespace:
#                             {'@id': 'bfe7bd8f-8dee-4635-b91c-
#                             9f27f685e926'}<br>owningRelationship: {'@id':
#                             '6498029a-0631-4235-bbdd-69137239903e'}<br>parameter:
#                             [{'@id': '82f9c8cf-
#                             ccdc-451b-bfdb-f6b30d06e8e5'}]<br>result: {'@id':
#                             '82f9c8cf-ccdc-451b-bfdb-f6b30d06e8e5'}<br>value: 5,
#                             @type: ReturnParameterMembership<br>@id:
#                             61c44910-2763-4639-85ca-c66ab45333c4<br>elementId:
#                             61c44910-2763-4639-85ca-c66ab45333c4<br>feature:
#                             {'@id': '4bb72d4d-80a0-4929-8144-
#                             af79ee772ad0'}<br>memberElement: {'@id': '4bb72d4d-
#                             80a0-4929-8144-af79ee772ad0'}<br>memberElementId:
#                             4bb72d4d-80a0-4929-8144-af79ee772ad0<br>memberName:
#                             result<br>membershipOwningNamespace: {'@id': '514de5e8-
#                             c6e5-44e3-ad67-27f371309ab4'}<br>ownedMemberElement:
#                             {'@id': '4bb72d4d-80a0-4929-8144-
#                             af79ee772ad0'}<br>ownedMemberElementId: 4bb72d4d-80a0-
#                             4929-8144-af79ee772ad0<br>ownedMemberFeature: {'@id': '
#                             4bb72d4d-80a0-4929-8144-
#                             af79ee772ad0'}<br>ownedMemberName:
#                             result<br>ownedMemberParameter: {'@id': '4bb72d4d-80a0-
#                             4929-8144-af79ee772ad0'}<br>ownedRelatedElement:
#                             [{'@id': '4bb72d4d-80a0-4929-8144-
#                             af79ee772ad0'}]<br>owningRelatedElement: {'@id':
#                             '514de5e8-c6e5-44e3-ad67-27f371309ab4'}<br>owningType:
#                             {'@id': '514de5e8-c6e5-44e3-ad67-
#                             27f371309ab4'}<br>relatedElement: [{'@id':
#                             '514de5e8-c6e5-44e3-ad67-27f371309ab4'}, {'@id':
#                             '4bb72d4d-80a0-4929-8144-af79ee772ad0'}]<br>source:
#                             [{'@id':
#                             '514de5e8-c6e5-44e3-ad67-27f371309ab4'}]<br>target:
#                             [{'@id':
#                             '4bb72d4d-80a0-4929-8144-af79ee772ad0'}]<br>type:
#                             {'@id':
#                             '514de5e8-c6e5-44e3-ad67-27f371309ab4'}<br>visibility:
#                             public, @type: Multiplicity<br>@id:
#                             ee7bd99a-5a99-4904-9af8-f7741c301b7b<br>elementId:
#                             ee7bd99a-5a99-4904-9af8-f7741c301b7b<br>isUnique:
#                             True<br>owner: {'@id': '9b768b3a-8afd-4eb5-b840-
#                             c76c9d0495cc'}<br>owningMembership: {'@id': 'b91f3d8a-
#                             b746-4256-906c-023263e73f11'}<br>owningNamespace:
#                             {'@id': '9b768b3a-8afd-4eb5-b840-
#                             c76c9d0495cc'}<br>owningRelationship: {'@id':
#                             'b91f3d8a-b746-4256-906c-023263e73f11'}, @type:
#                             OwningMembership<br>@id:
#                             b91f3d8a-b746-4256-906c-023263e73f11<br>elementId:
#                             b91f3d8a-b746-4256-906c-023263e73f11<br>memberElement:
#                             {'@id': 'ee7bd99a-5a99-4904-9af8-
#                             f7741c301b7b'}<br>memberElementId: ee7bd99a-5a99-4904-
#                             9af8-f7741c301b7b<br>membershipOwningNamespace: {'@id':
#                             '9b768b3a-8afd-4eb5-b840-
#                             c76c9d0495cc'}<br>ownedMemberElement: {'@id': 'ee7bd99a
#                             -5a99-4904-9af8-f7741c301b7b'}<br>ownedMemberElementId:
#                             ee7bd99a-5a99-4904-9af8-
#                             f7741c301b7b<br>ownedRelatedElement: [{'@id': 'ee7bd99a
#                             -5a99-4904-9af8-
#                             f7741c301b7b'}]<br>owningRelatedElement: {'@id': '9b768
#                             b3a-8afd-4eb5-b840-c76c9d0495cc'}<br>relatedElement:
#                             [{'@id': '9b768b3a-8afd-4eb5-b840-c76c9d0495cc'},
#                             {'@id':
#                             'ee7bd99a-5a99-4904-9af8-f7741c301b7b'}]<br>source:
#                             [{'@id':
#                             '9b768b3a-8afd-4eb5-b840-c76c9d0495cc'}]<br>target:
#                             [{'@id':
#                             'ee7bd99a-5a99-4904-9af8-f7741c301b7b'}]<br>visibility:
#                             public, @type: Membership<br>@id:
#                             9ff4e6c4-0771-43f6-b6d2-604a428cab82<br>elementId:
#                             9ff4e6c4-0771-43f6-b6d2-604a428cab82<br>memberElement:
#                             {'@id': 'bfe7bd8f-8dee-4635-b91c-
#                             9f27f685e926'}<br>memberElementId: bfe7bd8f-8dee-4635-
#                             b91c-9f27f685e926<br>membershipOwningNamespace: {'@id':
#                             'f716979c-3081-4119-b309-
#                             f3a28b435e3d'}<br>owningRelatedElement: {'@id': 'f71697
#                             9c-3081-4119-b309-f3a28b435e3d'}<br>relatedElement:
#                             [{'@id': 'f716979c-3081-4119-b309-f3a28b435e3d'},
#                             {'@id':
#                             'bfe7bd8f-8dee-4635-b91c-9f27f685e926'}]<br>source:
#                             [{'@id':
#                             'f716979c-3081-4119-b309-f3a28b435e3d'}]<br>target:
#                             [{'@id':
#                             'bfe7bd8f-8dee-4635-b91c-9f27f685e926'}]<br>visibility:
#                             public, @type: ReturnParameterMembership<br>@id:
#                             78e42437-720a-4636-b653-1369c87406c9<br>elementId:
#                             78e42437-720a-4636-b653-1369c87406c9<br>feature:
#                             {'@id': '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}<br>memberElement: {'@id':
#                             '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}<br>memberElementId:
#                             3c88341d-b1fa-4baf-aba7-f50984718f62<br>memberName:
#                             result<br>membershipOwningNamespace: {'@id': '1c289641-
#                             44bd-44a2-852e-1359a8ad3dbc'}<br>ownedMemberElement:
#                             {'@id': '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}<br>ownedMemberElementId:
#                             3c88341d-b1fa-4baf-
#                             aba7-f50984718f62<br>ownedMemberFeature: {'@id':
#                             '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}<br>ownedMemberName:
#                             result<br>ownedMemberParameter: {'@id':
#                             '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}<br>ownedRelatedElement: [{'@id':
#                             '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}]<br>owningRelatedElement: {'@id':
#                             '1c289641-44bd-44a2-852e-1359a8ad3dbc'}<br>owningType:
#                             {'@id': '1c289641-44bd-44a2-852e-
#                             1359a8ad3dbc'}<br>relatedElement: [{'@id':
#                             '1c289641-44bd-44a2-852e-1359a8ad3dbc'}, {'@id':
#                             '3c88341d-b1fa-4baf-aba7-f50984718f62'}]<br>source:
#                             [{'@id':
#                             '1c289641-44bd-44a2-852e-1359a8ad3dbc'}]<br>target:
#                             [{'@id': '3c88341d-b1fa-4baf-
#                             aba7-f50984718f62'}]<br>type: {'@id':
#                             '1c289641-44bd-44a2-852e-1359a8ad3dbc'}<br>visibility:
#                             public, @type: FeatureValue<br>@id:
#                             6498029a-0631-4235-bbdd-69137239903e<br>elementId: 6498
#                             029a-0631-4235-bbdd-69137239903e<br>featureWithValue:
#                             {'@id': 'bfe7bd8f-8dee-4635-b91c-
#                             9f27f685e926'}<br>memberElement: {'@id': '9ce85058-
#                             1a9c-4ab3-8d73-c543bf571655'}<br>memberElementId: 9ce85
#                             058-1a9c-4ab3-8d73-
#                             c543bf571655<br>membershipOwningNamespace: {'@id': 'bfe
#                             7bd8f-8dee-4635-b91c-
#                             9f27f685e926'}<br>ownedMemberElement: {'@id': '9ce85058
#                             -1a9c-4ab3-8d73-c543bf571655'}<br>ownedMemberElementId:
#                             9ce85058-1a9c-4ab3-8d73-
#                             c543bf571655<br>ownedRelatedElement: [{'@id': '9ce85058
#                             -1a9c-4ab3-8d73-
#                             c543bf571655'}]<br>owningRelatedElement: {'@id': 'bfe7b
#                             d8f-8dee-4635-b91c-9f27f685e926'}<br>relatedElement:
#                             [{'@id': 'bfe7bd8f-8dee-4635-b91c-9f27f685e926'},
#                             {'@id':
#                             '9ce85058-1a9c-4ab3-8d73-c543bf571655'}]<br>source:
#                             [{'@id':
#                             'bfe7bd8f-8dee-4635-b91c-9f27f685e926'}]<br>target:
#                             [{'@id':
#                             '9ce85058-1a9c-4ab3-8d73-c543bf571655'}]<br>value:
#                             {'@id':
#                             '9ce85058-1a9c-4ab3-8d73-c543bf571655'}<br>visibility:
#                             public],
#               'marker': {'color': 'LightSkyBlue', 'line': {'width': 2}, 'showscale': False, 'size': 10},
#               'mode': 'markers+text',
#               'text': [@type: FeatureMembership, @type: ReferenceUsage name:
#                        range, @type: PartUsage name: uav, @type: Feature name: y,
#                        @type: OperatorExpression operator: >=, @type:
#                        ParameterMembership, @type: FeatureReferenceExpression,
#                        @type: Feature name: x, @type: FeatureValue value: {'@id':
#                        '1c289641-44bd-44a2-852e-1359a8ad3dbc'}, @type:
#                        AttributeUsage name: measuredRange, @type: Feature name:
#                        result, @type: FeatureReferenceExpression, @type: Feature
#                        name: source, @type: FeatureValue value: {'@id':
#                        '03bc163d-47c3-40fa-bc57-52059aea2b57'}, @type: Feature
#                        name: result, @type: Feature name: result, @type:
#                        FeatureChainExpression operator: ., @type:
#                        ReturnParameterMembership, @type: ReturnParameterMembership,
#                        @type: FeatureValue value: {'@id':
#                        'f716979c-3081-4119-b309-f3a28b435e3d'}, @type:
#                        ParameterMembership, @type: LiteralInteger value: 1, @type:
#                        MultiplicityRange, @type: OwningMembership, @type: Feature
#                        name: result, @type: ParameterMembership, @type: Membership,
#                        @type: ResultExpressionMembership, @type: ConstraintUsage
#                        name: requiredRangeConstarint, @type: ReferenceUsage name:
#                        result, @type: Feature name: result, @type:
#                        ReturnParameterMembership, @type: OwningMembership, @type:
#                        Documentation, @type: Feature, @type: FeatureMembership,
#                        @type: ReturnParameterMembership, @type: Membership, @type:
#                        OwningMembership, @type: ReturnParameterMembership, @type:
#                        Feature name: result, @type: LiteralInteger value: 5, @type:
#                        ReturnParameterMembership, @type: Multiplicity, @type:
#                        OwningMembership, @type: Membership, @type:
#                        ReturnParameterMembership, @type: FeatureValue value:
#                        {'@id': '9ce85058-1a9c-4ab3-8d73-c543bf571655'}],
#               'textposition': 'bottom center',
#               'type': 'scatter',
#               'uid': '2f440e5c-31e2-455f-9440-dd4943b3e63c',
#               'x': [0.5440872570266438, 0.6010670706859121, 0.7906214454082733,
#                     -0.16249068577146508, -0.03473468245376464,
#                     -0.17837050514526415, -0.5687831814521391,
#                     -0.20432105888092542, -0.3972578706200559, -0.9579500738779916,
#                     -0.6657599592713762, 0.4338402881733586, 0.11890278810302121,
#                     0.25846917640499595, 0.4863213088533114, 0.2081769485389044,
#                     0.19633176920494866, 0.25075919634808647, 0.4439306680626343,
#                     0.0037799998430164245, -0.16652502132603336,
#                     0.17753440505569135, 0.10178238101321585, 0.18955456550429098,
#                     0.17880838078274403, 0.1321468834880217, -0.7680863940533388,
#                     -0.062551965703275, 0.05596638397852578, -0.015478476190037213,
#                     -0.10797568202324292, -0.06662073787748288,
#                     -0.9560231552235284, -1.0, 0.0018565524403043635,
#                     -0.003944385523629794, 0.22507129355534533, 0.6165024196726274,
#                     0.008756415264556266, 0.5259220576617981, 0.6204589180058296,
#                     0.6327586298899333, -0.04298491299600323, -0.9070886878895301,
#                     -0.8662428741940741, 0.38615895674903516, -0.6605607485195407,
#                     0.6041848992776738],
#               'y': [-0.6710658296776066, -0.7153886242971558, -0.7902352640533012,
#                     0.5133987220469122, 0.6627390907370506, 0.5530437823660893,
#                     -0.055238764295063025, 0.6110628705194397, 0.27882802135435614,
#                     -0.8018426120075965, -0.03615708854390336,
#                     -0.40065152277958377, -0.0397784800698241,
#                     -0.23739475233828783, -0.3759623430576142,
#                     -0.14625584770235825, -0.06869916914640757,
#                     -0.10762890207236464, -0.3370567903564562, 0.2140037243433855,
#                     0.6191260982120016, 0.7770500470595215, 0.8477047214557778,
#                     0.8786928030826977, 0.6477222195092112, -0.09353622661049654,
#                     -0.4275407887545579, 0.7232001548217545, 0.796319946873169,
#                     0.708622475697398, 0.5257631727785097, 0.5383958985507182,
#                     -0.6471550978391184, -0.7024170370096687, -0.11531722851970451,
#                     -0.0671888576382218, 0.6786189823203936, -0.5875578301492268,
#                     0.8126539761983602, -0.6369512493782009, -0.6838316708021355,
#                     -0.7715741059429597, 0.8035861880709235, -0.7327809557640357,
#                     -0.6309651785214218, -0.3997022998189474, -0.08681527983380785,
#                     -0.8238430990176425]}],
#     'layout': {'height': 800,
#                'hovermode': 'closest',
#                'margin': {'b': 20, 'l': 5, 'r': 5, 't': 40},
#                'showlegend': False,
#                'template': '...',
#                'title': {'font': {'size': 16}, 'text': 'Interactive SysMLv2 Network Graph'},
#                'xaxis': {'showgrid': False, 'showticklabels': False, 'zeroline': False},
#                'yaxis': {'showgrid': False, 'showticklabels': False, 'zeroline': False}}
# })
